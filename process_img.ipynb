# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from rembg.bg import remove
from PIL import Image
import os

import matplotlib.image as mpimg
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
def blur_color_img(img, kernel_width=5, kernel_height=5, sigma_x=2, sigma_y=2):
    img = np.copy(img) # we don't modify the original image
    img[:,:,0] = cv2.GaussianBlur(img[:,:,0], ksize=(kernel_width, kernel_height), sigmaX=sigma_x, sigmaY=sigma_y)
    img[:,:,1] = cv2.GaussianBlur(img[:,:,1], ksize=(kernel_width, kernel_height), sigmaX=sigma_x, sigmaY=sigma_y)
    img[:,:,2] = cv2.GaussianBlur(img[:,:,2], ksize=(kernel_width, kernel_height), sigmaX=sigma_x, sigmaY=sigma_y)
    return img

# %%
from rembg.bg import remove
from PIL import Image

# %%
# Tach nhung phan khong can thiet cua anh trong tap Tomato_Bacterial_spot

dir_data = "F:\\NCKH\\PlantVillage\\Tomato_Bacterial_spot\\"
path = "C:\\Users\\Admin\\Documents\\GitHub\\potato-disease-classification\\training\\\plant_dataset\\rembg\\Tomato_Bacterial_spot\\"
dataset = os.listdir(dir_data)


for i in range(len(dataset)):
    file_path = dir_data + dataset[i]    
    img = cv2.imread(file_path)
    
    input = Image.open(file_path)
    output = remove(input)
    output.save(f"{path}/{i}_Tomato_Bacterial_spot.png")

# %%
# Tach nhung phan khong can thiet cua anh trong tap Tomato_Early_blight

dir_data = "F:\\NCKH\\PlantVillage\\Tomato_Early_blight\\"
path = "C:\\Users\\Admin\\Documents\\GitHub\\potato-disease-classification\\training\\\plant_dataset\\rembg\\Tomato_Early_blight\\"
dataset = os.listdir(dir_data)


for i in range(len(dataset)):
    file_path = dir_data + dataset[i]    
    img = cv2.imread(file_path)
    
    input = Image.open(file_path)
    output = remove(input)
    output.save(f"{path}/{i}_Tomato_Early_blight.png")

# %%
# Tach nhung phan khong can thiet cua anh trong tap Tomato_healthy

dir_data = "F:\\NCKH\\PlantVillage\\Tomato_healthy\\"
path = "C:\\Users\\Admin\\Documents\\GitHub\\potato-disease-classification\\training\\\plant_dataset\\rembg\\Tomato_healthy\\"
dataset = os.listdir(dir_data)


for i in range(len(dataset)):
    file_path = dir_data + dataset[i]    
    img = cv2.imread(file_path)
    
    input = Image.open(file_path)
    output = remove(input)
    output.save(f"{path}/{i}_Tomato_healthy.png")

# %%
# Tach nhung phan khong can thiet cua anh trong tap Tomato_Late_blight

dir_data = "F:\\NCKH\\PlantVillage\\Tomato_Late_blight\\"
path = "C:\\Users\\Admin\\Documents\\GitHub\\potato-disease-classification\\training\\\plant_dataset\\rembg\\Tomato_Late_blight\\"
dataset = os.listdir(dir_data)


for i in range(len(dataset)):
    file_path = dir_data + dataset[i]    
    img = cv2.imread(file_path)
    
    input = Image.open(file_path)
    output = remove(input)
    output.save(f"{path}/{i}__Tomato_Late_blight.png")

# %%
# Tach nhung phan khong can thiet cua anh trong tap Tomato_Late_blight

dir_data = "F:\\NCKH\\PlantVillage\\Tomato_Late_blight\\"
path = "C:\\Users\\Admin\\Documents\\GitHub\\potato-disease-classification\\training\\\plant_dataset\\rembg\\Tomato_Late_blight\\"
dataset = os.listdir(dir_data)


for i in range(len(dataset)):
    file_path = dir_data + dataset[i]    
    img = cv2.imread(file_path)
    
    input = Image.open(file_path)
    output = remove(input)
    output.save(f"{path}/{i}__Tomato_Late_blight.png")

# %%
# Tach nhung phan khong can thiet cua anh trong tap Tomato_Leaf_Mold

dir_data = "F:\\NCKH\\PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\"
path = "F:\\NCKH\\plant\\Tomato_Spider_mites_Two_spotted_spider_mite\\"
dataset = os.listdir(dir_data)


for i in range(len(dataset)):
    file_path = dir_data + dataset[i]    
    img = cv2.imread(file_path)
    
    input = Image.open(file_path)
    output = remove(input)
    output.save(f"{path}/{i}__Tomato_Leaf_Mold.png")

# %%
dir_data = "F:\\NCKH\\Earrly blight\\"
path = "F:\\NCKH\\Earrly blight_remove\\"
dataset = os.listdir(dir_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 dir_data = "F:\\NCKH\\Earrly blight\\"
#       2 path = "F:\\NCKH\\Earrly blight_remove\\"
# ----> 3 dataset = os.listdir(dir_data)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'F:\\NCKH\\Earrly blight\\'

# %%
file_path = dir_data + dataset[0]    
img = cv2.imread(file_path)

# %%
# plt.subplot(121),
dim = (256,256)
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.figure()


plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB)),plt.title('Resize')
plt.xticks([]), plt.yticks([])
# plt.subplot(122),plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)),plt.title('Averaging')
# plt.xticks([]), plt.yticks([])
plt.show()

# %%
output = remove(img)
output = cv2.resize(output, dim, interpolation = cv2.INTER_AREA)

# %%
# plt.figure()
# plt.imshow(cv2.cvtColor(output, cv2.COLOR_BGR2RGB))
# plt.xticks([]), plt.yticks([])
# plt.axis("off")

plt.figure()
plt.imshow(cv2.cvtColor(output, cv2.COLOR_BGR2RGB))
# plt.xticks([]), plt.yticks([])
plt.axis("off")
# Out:
# (-0.5, 255.5, 255.5, -0.5)

# %%
input = Image.open(file_path)
output = remove(input)

# %%
plt.imshow(output),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.axis("off")
# Out:
# (-0.5, 1919.5, 2559.5, -0.5)

# %%
dir_data = "F:\\NCKH\\Earrly blight\\"
path = "F:\\NCKH\\Earrly blight remove\\"
dataset = os.listdir(dir_data)

for i in range(len(dataset)):
    file_path = dir_data + dataset[i]    
    img = cv2.imread(file_path)
    
    input = Image.open(file_path)
    output = remove(input)
    output.save(f"{path}/{i}__Tomato_early_blight.png")

# %%
path = "F:\\NCKH\\Earrly blight remove\\"
dataset = os.listdir(path)
for i in range(len(dataset)):
    file_path = path + dataset[i]
    img = cv2.imread(file_path)
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    
    plt.figure()
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.xticks([]), plt.yticks([])
    plt.axis("off")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2376\224105754.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
file_path = path + dataset[i]
img = cv2.imread(file_path)

# %%
dir_data = "F:\\NCKH\\rmbg\\"
path = "F:\\NCKH\\Earrly blight remove\\"
dataset = os.listdir(dir_data)
file_path = dir_data + dataset[0] 
for i in range(len(dataset)):
    file_path = dir_data + dataset[i]    
    img = cv2.imread(file_path)
    cv2.imwrite(f"{path}/{i}__Tomato_early_blight.png", img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [116], in <cell line: 5>()
#       6 file_path = dir_data + dataset[i]
#       7 img = cv2.imread(file_path)
# ----> 8 cv2.imwrite(f"{path}/{i}__Tomato_early_blight.png", img)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
file_path = dir_data + dataset[0] 
img = cv2.imread(file_path)

# %%
cv2.imwrite("original.png", img)
# Out:
# True

# %%
cv2.imwrite(f"original.png", img)
# Out:
# True

# %%
direc = "F:\\NCKH\\Earrly blight remove\\"
cv2.imwrite(f"{direc}original.png", img)
# Out:
# True

# %%
path = "F:\\NCKH\\Earrly blight remove\\"
dataset = os.listdir(path)

for i in range(len(dataset)):
    file_path = path + dataset[i]    
    img = cv2.imread(file_path)
    dst = cv.filter2D(img,-1,kernel)
    cv2.imwrite(f"{path}/avg_{i}__Tomato_early_blight.png", dst)

# %%
len(dataset)
# Out:
# 53

# %%
import cv2
file_path = path + dataset[i]
img = cv2.imread("original.png")    
plt.figure()
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.xticks([]), plt.yticks([])
plt.axis("off")

kernel = np.ones((5,5),np.float32)/25
dst = cv.filter2D(img,-1,kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
path = "F:\\NCKH\\Orinal_Earrly blight\\"
dataset = os.listdir(path)
file_path = path + dataset[44+2] 
file_path
# Out:
# 'F:\\NCKH\\Orinal_Earrly blight\\z3827058249376_6bb7182ae6db36ebc07d6211c93dc0d6.jpg'

# %%
img = cv2.imread(file_path)

# %%
file_path = dir_data + dataset[10]    
img = cv2.imread(file_path)

# %%
from matplotlib import pyplot as plt
import cv2 
# Load image
image_bgr = cv2.imread(file_path)
# Convert BGR to HSV
image_hsv = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2HSV)
lower_blue = np.array([10,10,50]) 
upper_blue = np.array([130,255,255])
mask = cv2.inRange(image_hsv, lower_blue, upper_blue)
# Mask image
image_bgr_masked = cv2.bitwise_and(image_bgr, image_bgr, mask=mask)
# Convert BGR to RGB
image_rgb = cv2.cvtColor(image_bgr_masked, cv2.COLOR_BGR2RGB)
# Show image
plt.imshow(mask), plt.axis("off")
plt.figure()
plt.imshow(image_bgr_masked), plt.axis("off")
plt.show()

# %%
# Show image
plt.imshow(image_hsv), plt.axis("off")
plt.show()

# %%
lower_blue
# Out:
# array([50, 40, 50])
